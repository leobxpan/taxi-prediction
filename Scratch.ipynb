# %%
import os
import torch
import numpy as np
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
import gc
import random
from sklearn.model_selection import train_test_split
import pdb

years = ['2014','2015','2016']
months = list(range(1,13))
time_suffix_lst = []
for yr in years:
    for month in months:
        time_suffix_lst.append(yr+'-'+'%02d'%month)
time_suffix_lst_2014 = time_suffix_lst[6:12]
time_suffix_lst = time_suffix_lst[12:-6]

csv_file_lst_2014 = ['yellow_tripdata_' + time_suffix + '.csv' for time_suffix in time_suffix_lst_2014]
csv_path_lst_2014 = [os.path.join('/home/lashi/assets', csv_file) for csv_file in csv_file_lst_2014]
csv_file_lst = ['yellow_tripdata_' + time_suffix + '.csv' for time_suffix in time_suffix_lst]
csv_path_lst = [os.path.join('/home/lashi/assets', csv_file) for csv_file in csv_file_lst]

# %%
for csv_path in csv_path_lst:
    file = open(csv_path,'r')
    print(csv_path)
    head = file.readline()
    print(head)
    head = head.split(',')
    print(len(head))
    line = file.readline().split(',')
    print(line)
#     print(file.readline())
    # print(file.readline())
    # print(file.readline())
    file.close()
    print('----\n-----')

# csv_path = '/home/lashi/assets/yellow_tripdata_2015-07.csv'
# file = open(csv_path,'r')
# print(file.readline())
# print(file.readline())
# # print(file.readline())
# # print(file.readline())
# file.close()

# csv_path = '/home/lashi/assets/yellow_tripdata_2015-06.csv'
# file = open(csv_path,'r')
# print(file.readline())
# print(file.readline())
# # print(file.readline())
# # print(file.readline())
# file.close()
# Out:
# /home/lashi/assets/yellow_tripdata_2015-01.csv
# VendorID,tpep_pickup_datetime,tpep_dropoff_datetime,passenger_count,trip_distance,pickup_longitude,pickup_latitude,RateCodeID,store_and_fwd_flag,dropoff_longitude,dropoff_latitude,payment_type,fare_amount,extra,mta_tax,tip_amount,tolls_amount,improvement_surcharge,total_amount
#
# 19
# ['2', '2015-01-15 19:05:39', '2015-01-15 19:23:42', '1', '1.59', '-73.993896484375', '40.750110626220703', '1', 'N', '-73.974784851074219', '40.750617980957031', '1', '12', '1', '0.5', '3.25', '0', '0.3', '17.05\n']
# ----
# -----
# /home/lashi/assets/yellow_tripdata_2015-02.csv
# VendorID,tpep_pickup_datetime,tpep_dropoff_datetime,passenger_count,trip_distance,pickup_longitude,pickup_latitude,RateCodeID,store_and_fwd_flag,dropoff_longitude,dropoff_latitude,payment_type,fare_amount,extra,mta_tax,tip_amount,tolls_amount,improvement_surcharge,total_amount
#
# 19
# ['2', '2015-02-08 11:33:46', '2015-02-08 11:37:45', '1', '.56', '-73.949905395507813', '40.717437744140625', '1', 'N', '-73.95001220703125', '40.724010467529297', '1', '4.5', '0', '0.5', '1.06', '0', '0.3', '6.36\n']
# ----
# -----
# /home/lashi/assets/yellow_tripdata_2015-03.csv
# VendorID,tpep_pickup_datetime,tpep_dropoff_datetime,passenger_count,trip_distance,pickup_longitude,pickup_latitude,RateCodeID,store_and_fwd_flag,dropoff_longitude,dropoff_latitude,payment_type,fare_amount,extra,mta_tax,tip_amount,tolls_amount,improvement_surcharge,total_amount
#
# 19
# ['1', '2015-03-06 08:02:31', '2015-03-06 08:09:55', '1', '1.20', '-73.990211486816406', '40.750968933105469', '1', 'N', '-73.987892150878906', '40.738037109375', '2', '7', '0', '0.5', '0', '0', '0.3', '7.8\n']
# ----
# -----
# /home/lashi/assets/yellow_tripdata_2015-04.csv
# VendorID,tpep_pickup_datetime,tpep_dropoff_datetime,passenger_count,trip_distance,pickup_longitude,pickup_latitude,RateCodeID,store_and_fwd_flag,dropoff_longitude,dropoff_latitude,payment_type,fare_amount,extra,mta_tax,tip_amount,tolls_amount,improvement_surcharge,total_amount
#
# 19
# ['2', '2015-04-27 15:16:29', '2015-04-27 15:26:14', '1', '1.05', '-73.988868713378906', '40.758396148681641', '1', 'N', '-73.984779357910156', '40.748271942138672', '2', '7.5', '0', '0.5', '0', '0', '0.3', '8.3\n']
# ----
# -----
# /home/lashi/assets/yellow_tripdata_2015-05.csv
# VendorID,tpep_pickup_datetime,tpep_dropoff_datetime,passenger_count,trip_distance,pickup_longitude,pickup_latitude,RateCodeID,store_and_fwd_flag,dropoff_longitude,dropoff_latitude,payment_type,fare_amount,extra,mta_tax,tip_amount,tolls_amount,improvement_surcharge,total_amount
#
# 19
# ['1', '2015-05-05 23:37:40', '2015-05-05 23:45:41', '1', '2.00', '-74.001678466796875', '40.739311218261719', '1', 'N', '-73.978294372558594', '40.752109527587891', '2', '8.5', '0.5', '0.5', '0', '0', '0.3', '9.8\n']
# ----
# -----
# /home/lashi/assets/yellow_tripdata_2015-06.csv
# VendorID,tpep_pickup_datetime,tpep_dropoff_datetime,passenger_count,trip_distance,pickup_longitude,pickup_latitude,RateCodeID,store_and_fwd_flag,dropoff_longitude,dropoff_latitude,payment_type,fare_amount,extra,mta_tax,tip_amount,tolls_amount,improvement_surcharge,total_amount
#
# 19
# ['2', '2015-06-02 11:19:29', '2015-06-02 11:47:52', '1', '1.63', '-73.954429626464844', '40.764141082763672', '1', 'N', '-73.974754333496094', '40.754093170166016', '2', '17', '0', '0.5', '0', '0', '0.3', '17.8\n']
# ----
# -----
# /home/lashi/assets/yellow_tripdata_2015-07.csv
# VendorID,tpep_pickup_datetime,tpep_dropoff_datetime,passenger_count,trip_distance,pickup_longitude,pickup_latitude,RatecodeID,store_and_fwd_flag,dropoff_longitude,dropoff_latitude,payment_type,fare_amount,extra,mta_tax,tip_amount,tolls_amount,improvement_surcharge,total_amount
#
# 19
# ['1', '2015-07-01 00:00:00', '2015-07-01 00:15:26', '1', '3.50', '-73.994155883789063', '40.751125335693359', '1', 'N', '-73.976821899414063', '40.788566589355469', '2', '14', '0.5', '0.5', '0', '0', '0.3', '15.3\n']
# ----
# -----
# /home/lashi/assets/yellow_tripdata_2015-08.csv
# VendorID,tpep_pickup_datetime,tpep_dropoff_datetime,passenger_count,trip_distance,pickup_longitude,pickup_latitude,RatecodeID,store_and_fwd_flag,dropoff_longitude,dropoff_latitude,payment_type,fare_amount,extra,mta_tax,tip_amount,tolls_amount,improvement_surcharge,total_amount
#
# 19
# ['2', '2015-08-01 00:00:15', '2015-08-01 00:36:21', '1', '7.22', '-73.999809265136719', '40.743339538574219', '1', 'N', '-73.942848205566406', '40.806621551513672', '2', '29.5', '0.5', '0.5', '0', '0', '0.3', '30.8\n']
# ----
# -----
# /home/lashi/assets/yellow_tripdata_2015-09.csv
# VendorID,tpep_pickup_datetime,tpep_dropoff_datetime,passenger_count,trip_distance,pickup_longitude,pickup_latitude,RatecodeID,store_and_fwd_flag,dropoff_longitude,dropoff_latitude,payment_type,fare_amount,extra,mta_tax,tip_amount,tolls_amount,improvement_surcharge,total_amount
#
# 19
# ['2', '2015-09-01 00:05:55', '2015-09-01 00:31:02', '1', '17.45', '-73.791351318359375', '40.646690368652344', '1', 'N', '-73.857437133789063', '40.848262786865234', '1', '47.5', '0.5', '0.5', '5', '5.54', '0.3', '59.34\n']
# ----
# -----
# /home/lashi/assets/yellow_tripdata_2015-10.csv
# VendorID,tpep_pickup_datetime,tpep_dropoff_datetime,passenger_count,trip_distance,pickup_longitude,pickup_latitude,RatecodeID,store_and_fwd_flag,dropoff_longitude,dropoff_latitude,payment_type,fare_amount,extra,mta_tax,tip_amount,tolls_amount,improvement_surcharge,total_amount
#
# 19
# ['1', '2015-10-01 00:00:00', '2015-10-01 00:05:48', '1', '1.10', '-73.935516357421875', '40.761238098144531', '1', 'N', '-73.944351196289063', '40.75457763671875', '2', '6', '0.5', '0.5', '0', '0', '0.3', '7.3\n']
# ----
# -----
# /home/lashi/assets/yellow_tripdata_2015-11.csv
# VendorID,tpep_pickup_datetime,tpep_dropoff_datetime,passenger_count,trip_distance,pickup_longitude,pickup_latitude,RatecodeID,store_and_fwd_flag,dropoff_longitude,dropoff_latitude,payment_type,fare_amount,extra,mta_tax,tip_amount,tolls_amount,improvement_surcharge,total_amount
#
# 19
# ['1', '2015-11-01 00:00:00', '2015-11-01 00:26:00', '1', '2.90', '-73.983993530273437', '40.729499816894531', '1', 'N', '-73.984550476074219', '40.759170532226563', '2', '17.5', '0.5', '0.5', '0', '0', '0.3', '18.8\n']
# ----
# -----
# /home/lashi/assets/yellow_tripdata_2015-12.csv
# VendorID,tpep_pickup_datetime,tpep_dropoff_datetime,passenger_count,trip_distance,pickup_longitude,pickup_latitude,RatecodeID,store_and_fwd_flag,dropoff_longitude,dropoff_latitude,payment_type,fare_amount,extra,mta_tax,tip_amount,tolls_amount,improvement_surcharge,total_amount
#
# 19
# ['2', '2015-12-01 00:00:00', '2015-12-01 00:05:16', '5', '.96', '-73.979942321777344', '40.765380859375', '1', 'N', '-73.96630859375', '40.763088226318359', '1', '5.5', '0.5', '0.5', '1', '0', '0.3', '7.8\n']
# ----
# -----
# /home/lashi/assets/yellow_tripdata_2016-01.csv
# VendorID,tpep_pickup_datetime,tpep_dropoff_datetime,passenger_count,trip_distance,pickup_longitude,pickup_latitude,RatecodeID,store_and_fwd_flag,dropoff_longitude,dropoff_latitude,payment_type,fare_amount,extra,mta_tax,tip_amount,tolls_amount,improvement_surcharge,total_amount
#
# 19
# ['2', '2016-01-01 00:00:00', '2016-01-01 00:00:00', '2', '1.10', '-73.990371704101563', '40.734695434570313', '1', 'N', '-73.981842041015625', '40.732406616210937', '2', '7.5', '0.5', '0.5', '0', '0', '0.3', '8.8\n']
# ----
# -----
# /home/lashi/assets/yellow_tripdata_2016-02.csv
# VendorID,tpep_pickup_datetime,tpep_dropoff_datetime,passenger_count,trip_distance,pickup_longitude,pickup_latitude,RatecodeID,store_and_fwd_flag,dropoff_longitude,dropoff_latitude,payment_type,fare_amount,extra,mta_tax,tip_amount,tolls_amount,improvement_surcharge,total_amount
#
# 19
# ['2', '2016-02-25 17:24:20', '2016-02-25 17:27:20', '2', '.70', '-73.947250366210937', '40.763771057128906', '1', 'N', '-73.992012023925781', '40.735389709472656', '2', '5', '0', '0.5', '0', '0', '0.3', '5.8\n']
# ----
# -----
# /home/lashi/assets/yellow_tripdata_2016-03.csv
# VendorID,tpep_pickup_datetime,tpep_dropoff_datetime,passenger_count,trip_distance,pickup_longitude,pickup_latitude,RatecodeID,store_and_fwd_flag,dropoff_longitude,dropoff_latitude,payment_type,fare_amount,extra,mta_tax,tip_amount,tolls_amount,improvement_surcharge,total_amount
#
# 19
# ['1', '2016-03-01 00:00:00', '2016-03-01 00:07:55', '1', '2.50', '-73.97674560546875', '40.765151977539062', '1', 'N', '-74.004264831542969', '40.746128082275391', '1', '9', '0.5', '0.5', '2.05', '0', '0.3', '12.35\n']
# ----
# -----
# /home/lashi/assets/yellow_tripdata_2016-04.csv
# VendorID,tpep_pickup_datetime,tpep_dropoff_datetime,passenger_count,trip_distance,pickup_longitude,pickup_latitude,RatecodeID,store_and_fwd_flag,dropoff_longitude,dropoff_latitude,payment_type,fare_amount,extra,mta_tax,tip_amount,tolls_amount,improvement_surcharge,total_amount
#
# 19
# ['1', '2016-04-01 00:00:00', '2016-04-01 00:01:59', '1', '.50', '-73.976882934570313', '40.758495330810547', '1', 'N', '-73.977668762207031', '40.753902435302734', '2', '3.5', '0.5', '0.5', '0', '0', '0.3', '4.8\n']
# ----
# -----
# /home/lashi/assets/yellow_tripdata_2016-05.csv
# VendorID,tpep_pickup_datetime,tpep_dropoff_datetime,passenger_count,trip_distance,pickup_longitude,pickup_latitude,RatecodeID,store_and_fwd_flag,dropoff_longitude,dropoff_latitude,payment_type,fare_amount,extra,mta_tax,tip_amount,tolls_amount,improvement_surcharge,total_amount
#
# 19
# ['1', '2016-05-01 00:00:00', '2016-05-01 00:17:31', '1', '3.60', '-73.98590087890625', '40.768039703369141', '1', 'N', '-73.983985900878906', '40.730098724365234', '1', '15', '0.5', '0.5', '1.5', '0', '0.3', '17.8\n']
# ----
# -----
# /home/lashi/assets/yellow_tripdata_2016-06.csv
# VendorID,tpep_pickup_datetime,tpep_dropoff_datetime,passenger_count,trip_distance,pickup_longitude,pickup_latitude,RatecodeID,store_and_fwd_flag,dropoff_longitude,dropoff_latitude,payment_type,fare_amount,extra,mta_tax,tip_amount,tolls_amount,improvement_surcharge,total_amount
#
# 19
# ['2', '2016-06-09 21:06:36', '2016-06-09 21:13:08', '2', '.79', '-73.983360290527344', '40.760936737060547', '1', 'N', '-73.977462768554688', '40.753978729248047', '2', '6', '0.5', '0.5', '0', '0', '0.3', '7.3\n']
# ----
# -----
